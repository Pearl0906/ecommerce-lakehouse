# %%
CREATE OR REFRESH STREAMING TABLE bronze_users
AS SELECT *,
  current_timestamp() AS _ingestion_timestamp,
  _metadata.file_name AS _source_file
FROM STREAM read_files(
  '/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/',
  format => 'csv',
  header => true,
  schemaLocation => '/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/users.csv',
  fileNamePattern => 'users.csv'
);

# %%
CREATE OR REFRESH STREAMING TABLE bronze_reviews
AS SELECT *,
  current_timestamp() AS _ingestion_timestamp,
  _metadata.file_name AS _source_file
FROM STREAM read_files(
  '/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/',
  format => 'csv',
  header => true,
  schemaLocation => '/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/reviews.csv',
  fileNamePattern => 'reviews.csv'
);

# %%
CREATE OR REFRESH STREAMING TABLE bronze_products
AS SELECT *,
  current_timestamp() AS _ingestion_timestamp,
  _metadata.file_name AS _source_file
FROM STREAM read_files(
  '/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/',
  format => 'csv',
  header => true,
  schemaLocation => '/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/products.csv',
  fileNamePattern => 'products.csv'
);

# %%
DROP TABLE IF EXISTS workspace.default.bronze_orders;

CREATE STREAMING TABLE bronze_orders
AS SELECT *,
  current_timestamp() AS _ingestion_timestamp,
  _metadata.file_name AS _source_file
FROM STREAM read_files(
  '/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/',
  format => 'csv',
  header => true,
  schemaLocation => '/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/orders.csv',
  fileNamePattern => 'orders.csv'
);

# %%
CREATE OR REFRESH STREAMING TABLE bronze_order_items
AS SELECT *,
current_timestamp() AS _ingestion_timestamp,
_metadata.file_name AS _source_file
FROM STREAM read_files(
'/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/',
format => 'csv',
header => true,
schemaLocation => '/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/order_items.csv',
fileNamePattern => 'order_items.csv'
);

# %%
CREATE OR REFRESH STREAMING TABLE bronze_events
AS SELECT *,
  current_timestamp() AS _ingestion_timestamp,
  _metadata.file_name AS _source_file
FROM STREAM read_files(
  '/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/',
  format => 'csv',
  header => true,
  schemaLocation => '/Volumes/e-commerce/ecommerce/raw_data/ecommerce_dataset/events.csv',
  fileNamePattern => 'events.csv'
);
